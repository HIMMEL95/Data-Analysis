# %% [markdown]
# # 2.1) 나무위키 최신 변경 문서의 키워드 분석
# 바로가기
# * <Step1. 크롤링> : 크롤링으로 웹 데이터 가져오기
#     * [BeautifulSoup을 이용한 웹 크롤링]
#     * [나무위키 최근변경 데이터 크롤링]
# * <Step2. 추출> : 키워드 추출
#     * [텍스트 데이터 전처리]
#     * [말뭉치 만들기]
#     * [konlpy를 이용한 키워드 추출]
#     * [키워드 가다듬기]
# * <Step3. 시각화> : 워드 클라우드 시각화
#     * [pytagcloud 사용하기]
#     * [나무위키 키워드 시각화]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 

import warnings
warnings.filterwarnings('ignore')
# Out:
# /home/himmel/.local/lib/python3.7/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# # <Step1. 크롤링> : 크롤링으로 웹 데이터 가져오기
#
# [BeautifulSoup을 이용한 웹 크롤링]
#
# * 아래 코드 실행을 위해, anaconda prompt 혹은 Terminal에서 아래와 같은 패키지들을 설치해 줍니다.
#     * (env_name) pip install requests
#     * (env_name) pip install beautifulsoup4
#     * (env_name) pip install lxml
# * 혹은 아래의 코드로 라이브러리를 설치합니다.

# %%
# !pip install requests beautifulsoup4 lxml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /home/himmel/.local/lib/python3.9/site-packages (2.25.1)
# Requirement already satisfied: beautifulsoup4 in /home/himmel/.local/lib/python3.9/site-packages (4.9.3)
# Requirement already satisfied: lxml in /home/himmel/.local/lib/python3.9/site-packages (4.6.2)
# Requirement already satisfied: soupsieve>1.2 in /home/himmel/.local/lib/python3.9/site-packages (from beautifulsoup4) (2.1)
# Requirement already satisfied: idna<3,>=2.5 in /home/himmel/.local/lib/python3.9/site-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/himmel/.local/lib/python3.9/site-packages (from requests) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/himmel/.local/lib/python3.9/site-packages (from requests) (1.26.2)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/himmel/.local/lib/python3.9/site-packages (from requests) (4.0.0)

# %% [markdown]
# # 페이지 리스트 가져오기

# %%
import requests
from bs4 import BeautifulSoup
import re

# 크롤링할 사이트 주소를 정의합니다.
source_url = "https://namu.wiki/RecentChanges"

# 사이트의 html 구조에 기반하여 크롤링을 수행합니다.
req = requests.get(source_url)
html = req.content
soup = BeautifulSoup(html, 'lxml')
contents_table = soup.find(name="table")
table_body = contents_table.find(name="tbody")
table_rows = table_body.find_all(name="tr")

# %%
# a태그의 href 속성을 리스트로 추출하여, 크롤링 할 페이지 리스트를 생성합니다.
page_url_base = "https://namu.wiki"
page_urls = []
for index in range(0, len(table_rows)):
    first_td = table_rows[index].find_all('td')[0]
    td_url = first_td.find_all('a')
    if len(td_url) > 0:
        page_url = page_url_base + td_url[0].get('href')
        if 'png' not in page_url:
            page_urls.append(page_url)

# 중복 url을 제거합니다.
page_urls = list(set(page_urls))
for page in page_urls[:5]:
    print(page)
# Out:
# https://namu.wiki/w/%EB%9D%BC%EB%A9%B4%20%EC%82%BC%EC%B4%9D%EC%82%AC
# https://namu.wiki/w/%EB%A7%88%EC%9D%B4%EC%95%A0%EB%AF%B8%20%EB%8F%8C%ED%95%80%EC%8A%A4
# https://namu.wiki/w/%EC%95%84%EC%9D%B4%ED%8F%B0%EC%9D%84%20%EC%82%AC%EA%B3%A0%20%EB%82%98%EC%84%9C%20%EB%82%B4%20%EC%9D%B8%EC%83%9D%EC%9D%B4%20%EB%8B%AC%EB%9D%BC%EC%A1%8C%EB%8B%A4
# https://namu.wiki/w/%EC%9C%A0%EC%9E%90%ED%82%A4%20%EC%B8%A0%EC%B9%B4%EC%82%AC
# https://namu.wiki/w/%EB%86%8D%EC%96%B4%EC%B4%8C%EB%B2%84%EC%8A%A4%20%EB%8B%A8%EC%9D%BC%EC%9A%94%EA%B8%88%EC%A0%9C

# %% [markdown]
# # 페이지내 텍스트 구조 확인

# %%
req = requests.get(page_urls[0])
html = req.content
soup = BeautifulSoup(html, 'html.parser')
contents_table = soup.find(name="article")
title = contents_table.find_all('h1')[0]
category = contents_table.find_all('ul')[0]
content_paragraphs = contents_table.find_all(name="div", attrs={"class":"wiki-paragraph"})
content_corpus_list = []

for paragraphs in content_paragraphs:
    content_corpus_list.append(paragraphs.text)
content_corpus = "".join(content_corpus_list)

print(title.text)
print("\n")
print(category.text)
print("\n")
print(content_corpus)
# Out:
# 라면 삼총사
#
#
# 맛의 달인짤방/만화인터넷 밈/만화 및 애니메이션문서 삭제식 이동명수 3
#
#
# ラーメン三銃士1. 개요2. 상세3. 구성원4. 기타4.1. 번역 문제4.2. 개노답 삼형제4.2.1. 패러디 예시원본한국어 발매본나가이: 기다렸지―――! 라면 삼총사를 데려왔단다.금은면 모녀: 라면 삼총사?나가이: 면 전문가, 다이시 유조.유조: 여, 잘 부탁합니다.나가이: 수프 전문가, 데가와 미노루.데가와: 열심히 할게요, 잘 부탁드립니다.나가이: 차슈, 멘마 등 고명 전문가, 타키 야스시.타키: 여, 실례합니다.《맛의 달인》38권 '라면 전쟁' 편의 등장 인물들.[1]해당 에피소드는 점포를 공격적으로 확장하는 '유성면(流星組)'으로부터, 죽은 남편의 라면집 '금은면(金銀軒)'을 아들과 함께 운영하는 여주인을 돕는 내용을 다루고 있다. 실제 원작에선 패러디와 다르게 절대 개노답인 사람들이 아니며, 오히려 저 망해가는 라면집을 살리기 위해 자신의 일인 것 마냥 무보수 무대가로 나서서 도와주는 대인배 요리사들이다. 그리고 각자의 성이 다른 것에서 알 수 있듯 친형제도 아니다.라면 삼총사를 소개하는 사람은 금은면 주인을 돕기 위해 지로가 찾아간 라면 종합 개발연구소의 소장 나가이.[2] 나름 라면 외길 50년에 전국에 200여개의 지부에 200만 명 가까이 넘는 회원을 거느린 라면계의 거물. 하지만 처음 본 지로 일행에게 '라면이 세계를 구한다!'라는 구호를 외치게 하는 걸 보면… 유성면의 사장 키지카와가 뛰어난 요리사라, 그에 대항하기 위해 부른 게 바로 이 라면 삼총사. 지금까지 다양한 라멘가게를 재건시키는 데에 성공한 라멘 가게 재건 전문가들이라고 한다. 이들 역시 뛰어난 라면 요리사이긴 하지만... 키지카와에게 발렸다. 결국 쿠리타 유우코의 부탁을 받은 카이바라 유우잔이 방법을 가르쳐 줘서 이긴다.[3] 물론 카이바라는 마지막 힌트만 준 것이고 기본적인 틀은 이 세 명이 잡아준 것이다.어쨌든 요리 승부에 패한 키지카와는 결과를 받아들이고 물러선다. 참고로 키지카와는 일단 적으로 나왔고 다소 독선적인 면은 있지만, 뛰어난 요리사인데다 사장으로서의 마인드도 훌륭한 인물이다.이후의 에피소드에서도 일본 라면 총합개발연구원 소장인 나가이나 금은면의 인물들은 재등장하지만, 그들이 다시 등장하는 일은 없었다. 엄밀히 말하자면 이들은 '가게 재건 전문가'인 만큼 자주 등장시키기 어렵다는 점도 고려해야겠지만.다이시 유조(乃士勇造)면 전문가. 작중에서는 면의 재질이나 식감, 더 나아가서 밀가루 선정까지 관여했기에 제법 활약이 컸다.데가와 미노루(出川実)수프(국물) 전문가. 면 다음으로 중요한 분야인 만큼 그럭저럭 옆에서 코치해주었다.타키 야스시(多木康)[4]고명 전문가. 본인은 옆에서 고명의 중요성을 설파하기는 했지만 안타깝게도 가장 활약이 없었다. 각종 패러디짤에서는 끝마무리를 장식하는 포지션으로, 대부분 가장 노답인 사례를 담당하고 있다.본 에피소드의 영향인지, 훗날 연재된 다른 요리 만화에서도 라멘 가게를 경영하는 내용을 다룰 경우엔 등장인물 서너 명이 경영 부진을 겪는 가게를 돕는 전개가 나올 때가 있다. 그 때마다 일본 웹상에서는 해당 작품의 묘사와 삼총사의 행적을 비교하기도 한다.맛의 달인 애니판은 27권까지의 내용만 다루고 있기 때문에 38권에 나오는 본 인물들은 출연하지 않는다.야한 이야기라는 개념이 존재하지 않는 지루한 세계 애니판에서는 느닷없이 학생회장을 습격하는 스토커 역할로 카메오 출연하기도 했다.참고로 마지막 3컷의 번역은 오역이다. 말풍선의 표시를 보면 오른쪽 말풍선은 왼쪽과 달리 말하는 당사자를 표시해주는 뾰족한 부분이 없는, 칸 바깥 인물의 대사인 것을 알 수 있다. 극 용어로 치면 보이스오버(Voice-over). 처음엔 "라면 전문가들을 모아왔지."라며 반말(즉 말투 중 ‘해체’)을 사용하다가, 소개 부분에선 존댓말을 쓰는 것도 오류.아마도 번역자는 하단 세 칸의 말풍선 내 대사들 전부가 라면 삼총사 각자 직접 한 말로 착각한 것 같은데, 실제로는 먼저 오른쪽에서 칸 바깥의 나가이 소장이 인물에 대한 소개를 하고 나서, 그에 대해 소개된 본인이 인사하는 것으로 이해하는 것이 정확하다. 게다가 마지막 사람은 소개마저도 미묘하게 잘못 번역되었다. '차슈, 말린 죽순 등 고명 전문가'라고 번역해야 했다. 정발번역만 보면 원래 차슈와 말린 죽순은 고명의 일종인데 마치 차슈와 말린 죽순이 고명과 동격인 것처럼 보인다.작중에서는 어디까지나 라면에 대한 지식과 조력을 담당하는 단역들에 불과했으나, 그 개성적인 외모와 옷차림[5]이 주는 임팩트, 그리고 여러모로 활용도가 높은 소개 장면의 컷 구성으로 인해 온갖 답이 없는 것들로 패러디되기 시작했다.문제의 컷은 후타바 채널에서 진즉에 패러디 짤로 돌아다니다가, 2014년 10월경부터 트위터에서 패러디 소재로 재발굴되며 급속도로 유행하기 시작했다. 이렇게 생겨난 각종 인터넷 짤방들은 한국에 전파되면서 라면 삼총사 대신 대부분 개노답 삼형제라는 별칭으로 알려져있으며, 그 외로 개노답 삼총사, 개노답 삼인방 등으로도 불린다.본래 일본에서 유행하던 것이 건너온 것이며, 어떠한 주제에 대한 세 가지의 악례를 세 사람에게 각각 대입시켜 보는 사람으로 하여금 '그래 꼭 저런 사람 있어' 라는 공감과 동시에 답이 없다는 느낌을 주는 것을 의도하고 있다.대사만 바꾸면 뭘 어째도 그럴듯해 보이는 만능성 때문에 트위터 및 인터넷 커뮤니티 게시판을 필두로 계속 새로운 버전이 나오고 있다. 대다수의 패러디에서 원본과 다른 특징이라면 "삼총사를 모아왔지"라는 대사가 "~ 개노답 3형제다!"라는 대사로 바뀌고, 마지막 인물의 소개 때 "그 중에서도 가장 악질인~"[6]or"얘는 왜 지가 욕먹는지 모를꺼야"이라는 대사가 자주 쓰인다.보통 패러디될 때 왼쪽 인물이 가장 심각한 케이스로 묘사되고 이로 인해 대사 끝에 "이 새낀 지가 왜 욕처먹는지도 모를 거야 아마" 혹은"이 새낀 ~~일 거야" 라는 대사가 들어가는 경우가 많다. 그걸 받아주는 마지막 인물은 보통 "XXX는 하셨는지?"라는 말을 하는데, 이를 볼 때 "가장 악질" 대사와 "왜 욕처먹는지도 모를 거야" 대사는 루리웹 버전에서부터 유래했을 가능성이 크다.[7]원작이 일본만화다 보니 우→좌 방향으로 보는 사람도 있고, 반대로 일반적인 좌→우 방향으로 보는 사람도 있다. 사실 패러디물 대부분이 어느 방향으로 봐도 지장없게 구성되긴 해서 별 얘기는 없다.그 인기에 힘입어 그 후속 장면이 발굴되었다. 일본만화이므로 오른쪽에서 왼쪽으로 읽을 것. 일명 개노답 삼형제 속편. 서로 싸우는 상황이므로 개노답성을 더 강하게 보여줄 수 있지만 싸워야 하기 때문에 상황이 한정되기도 하고 발굴 자체가 늦어져서 이 쪽 패러디는 많지 않다.[8]젤다의 전설 트라이포스 삼총사의 별명이 젤다의 전설 개노답 삼총사다. 게임 특성상 싱글 플레이가 힘들다는 점과, 멀티 플레이시 서로의 생각이 꼬여버리면 클리어가 힘들다는 점에서 나온 별명.한 트위터리안은 아예 간단히 대사를 넣어 패러디를 만들수 있는 생성기를 만들었다. 일본쪽에도 생성기가 있다.[9] 한국에서도 이미지 파일로 생성이 가능한 생성기가 있다.일본의 패러디들가면라이더가면라이더 버전 개노답 삼형제가을철 피부 개노답 삼형제갑판지옥 삼형제 개노답 삼형제건담 빌드 파이터즈 트라이 버전 개노답 트라이 파이터즈건담 철혈의 오펀스 개노답 삼형제건담 시리즈 미제작인데 철혈이 건담시리즈에서 제일 악질적이긴 하다...검정 고무신 4 개노답 삼형제게이망가 개노답 삼형제겐트위한군 간부 개노답 삼형제 - 장교버전 부사관 버전곤충 표본 개노답삼형제게임계 개노답 삼형제겟앰프드 개노답 삼형제기동전사 건담 시리즈의 개노답 삼형제 셋 다 동일인물인건 넘어가자니세코이 개노답 삼남매닌닌저 개노답 삼형제닌자고 개노답 삼형제내 맘대로 Z9별 개노답 삼형제네이버 웹툰 잼민이 개노답 삼형제네티즌 개노답 삼형제다이어트 개노답 삼형제더게임툰 53화도타 2 개노답 삼형제, 개노답 삼형제 2, 개노답 삼형제 3. 6.84 개노답 삼형제동북아 코로나 개노답 3형제디시 갤러리 개노답 삼형제디지몬 시리즈디지몬 어드벤처 트라이 개노답 삼형제디지몬 제작진 개노답 삼형제Don't Hug Me I'm Scared 개노답 사형제 개노답 오형제 개노답 육형제 [10][11]동아 ...

# %% [markdown]
# # [나무위키 최근변경 데이터 크롤링]

# %%
# 크롤링한 데이터를 데이터 프레임으로 만들기 위해 준비합니다.
columns = ['title', 'category', 'content_text']
df = pd.DataFrame(columns=columns)

# 각 페이지별 '제목', '카테고리', '본문' 정보를 데이터 프레임으로 만듭니다.
for page_url in page_urls:

    # 사이트의 html 구조에 기반하여 크롤링을 수행합니다.
    req = requests.get(page_url)
    html = req.content
    soup = BeautifulSoup(html, 'lxml')
    contents_table = soup.find(name="article")
    title = contents_table.find_all('h1')[0]
    
    # 카테고리 정보가 없는 경우를 확인합니다.
    if len(contents_table.find_all('ul')) > 0:
        category = contents_table.find_all('ul')[0]
    else:
        category = None
        
    content_paragraphs = contents_table.find_all(name="div", attrs={"class":"wiki-paragraph"})
    content_corpus_list = []
    
    # 페이지 내 제목 정보에서 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if title is not None:
        row_title = title.text.replace("\n", " ")
    else:
        row_title = ""
    
    # 페이지 내 본문 정보에서 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if content_paragraphs is not None:
        for paragraphs in content_paragraphs:
            if paragraphs is not None:
                content_corpus_list.append(paragraphs.text.replace("\n", " "))
            else:
                content_corpus_list.append("")
    else:
        content_corpus_list.append("")
        
    # 페이지 내 카테고리정보에서 “분류”라는 단어와 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if category is not None:
        row_category = category.text.replace("\n", " ")
    else:
        row_category = ""
    
    # 모든 정보를 하나의 데이터 프레임에 저장합니다.
    row = [row_title, row_category, "".join(content_corpus_list)]
    series = pd.Series(row, index=df.columns)
    df = df.append(series, ignore_index=True)

# %% [markdown]
# # <Step2. 추출> : 키워드 추출
#
# * 텍스트 데이터 전처리

# %%
# 텍스트 정제 함수 : 한글 이외의 문자는 전부 제거합니다.
def text_cleaning(text):
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+') # 한글의 정규표현식을 나타냅니다.
    result = hangul.sub('', text)
    return result

# %%
print(text_cleaning(df['content_text'][0]))
# Out:
#  개요 상세 구성원 기타 번역 문제 개노답 삼형제 패러디 예시원본한국어 발매본나가이 기다렸지 라면 삼총사를 데려왔단다금은면 모녀 라면 삼총사나가이 면 전문가 다이시 유조유조 여 잘 부탁합니다나가이 수프 전문가 데가와 미노루데가와 열심히 할게요 잘 부탁드립니다나가이 차슈 멘마 등 고명 전문가 타키 야스시타키 여 실례합니다맛의 달인권 라면 전쟁 편의 등장 인물들해당 에피소드는 점포를 공격적으로 확장하는 유성면으로부터 죽은 남편의 라면집 금은면을 아들과 함께 운영하는 여주인을 돕는 내용을 다루고 있다 실제 원작에선 패러디와 다르게 절대 개노답인 사람들이 아니며 오히려 저 망해가는 라면집을 살리기 위해 자신의 일인 것 마냥 무보수 무대가로 나서서 도와주는 대인배 요리사들이다 그리고 각자의 성이 다른 것에서 알 수 있듯 친형제도 아니다라면 삼총사를 소개하는 사람은 금은면 주인을 돕기 위해 지로가 찾아간 라면 종합 개발연구소의 소장 나가이 나름 라면 외길 년에 전국에 여개의 지부에 만 명 가까이 넘는 회원을 거느린 라면계의 거물 하지만 처음 본 지로 일행에게 라면이 세계를 구한다라는 구호를 외치게 하는 걸 보면 유성면의 사장 키지카와가 뛰어난 요리사라 그에 대항하기 위해 부른 게 바로 이 라면 삼총사 지금까지 다양한 라멘가게를 재건시키는 데에 성공한 라멘 가게 재건 전문가들이라고 한다 이들 역시 뛰어난 라면 요리사이긴 하지만 키지카와에게 발렸다 결국 쿠리타 유우코의 부탁을 받은 카이바라 유우잔이 방법을 가르쳐 줘서 이긴다 물론 카이바라는 마지막 힌트만 준 것이고 기본적인 틀은 이 세 명이 잡아준 것이다어쨌든 요리 승부에 패한 키지카와는 결과를 받아들이고 물러선다 참고로 키지카와는 일단 적으로 나왔고 다소 독선적인 면은 있지만 뛰어난 요리사인데다 사장으로서의 마인드도 훌륭한 인물이다이후의 에피소드에서도 일본 라면 총합개발연구원 소장인 나가이나 금은면의 인물들은 재등장하지만 그들이 다시 등장하는 일은 없었다 엄밀히 말하자면 이들은 가게 재건 전문가인 만큼 자주 등장시키기 어렵다는 점도 고려해야겠지만다이시 유조면 전문가 작중에서는 면의 재질이나 식감 더 나아가서 밀가루 선정까지 관여했기에 제법 활약이 컸다데가와 미노루수프국물 전문가 면 다음으로 중요한 분야인 만큼 그럭저럭 옆에서 코치해주었다타키 야스시고명 전문가 본인은 옆에서 고명의 중요성을 설파하기는 했지만 안타깝게도 가장 활약이 없었다 각종 패러디짤에서는 끝마무리를 장식하는 포지션으로 대부분 가장 노답인 사례를 담당하고 있다본 에피소드의 영향인지 훗날 연재된 다른 요리 만화에서도 라멘 가게를 경영하는 내용을 다룰 경우엔 등장인물 서너 명이 경영 부진을 겪는 가게를 돕는 전개가 나올 때가 있다 그 때마다 일본 웹상에서는 해당 작품의 묘사와 삼총사의 행적을 비교하기도 한다맛의 달인 애니판은 권까지의 내용만 다루고 있기 때문에 권에 나오는 본 인물들은 출연하지 않는다야한 이야기라는 개념이 존재하지 않는 지루한 세계 애니판에서는 느닷없이 학생회장을 습격하는 스토커 역할로 카메오 출연하기도 했다참고로 마지막 컷의 번역은 오역이다 말풍선의 표시를 보면 오른쪽 말풍선은 왼쪽과 달리 말하는 당사자를 표시해주는 뾰족한 부분이 없는 칸 바깥 인물의 대사인 것을 알 수 있다 극 용어로 치면 보이스오버 처음엔 라면 전문가들을 모아왔지라며 반말즉 말투 중 해체을 사용하다가 소개 부분에선 존댓말을 쓰는 것도 오류아마도 번역자는 하단 세 칸의 말풍선 내 대사들 전부가 라면 삼총사 각자 직접 한 말로 착각한 것 같은데 실제로는 먼저 오른쪽에서 칸 바깥의 나가이 소장이 인물에 대한 소개를 하고 나서 그에 대해 소개된 본인이 인사하는 것으로 이해하는 것이 정확하다 게다가 마지막 사람은 소개마저도 미묘하게 잘못 번역되었다 차슈 말린 죽순 등 고명 전문가라고 번역해야 했다 정발번역만 보면 원래 차슈와 말린 죽순은 고명의 일종인데 마치 차슈와 말린 죽순이 고명과 동격인 것처럼 보인다작중에서는 어디까지나 라면에 대한 지식과 조력을 담당하는 단역들에 불과했으나 그 개성적인 외모와 옷차림이 주는 임팩트 그리고 여러모로 활용도가 높은 소개 장면의 컷 구성으로 인해 온갖 답이 없는 것들로 패러디되기 시작했다문제의 컷은 후타바 채널에서 진즉에 패러디 짤로 돌아다니다가 년 월경부터 트위터에서 패러디 소재로 재발굴되며 급속도로 유행하기 시작했다 이렇게 생겨난 각종 인터넷 짤방들은 한국에 전파되면서 라면 삼총사 대신 대부분 개노답 삼형제라는 별칭으로 알려져있으며 그 외로 개노답 삼총사 개노답 삼인방 등으로도 불린다본래 일본에서 유행하던 것이 건너온 것이며 어떠한 주제에 대한 세 가지의 악례를 세 사람에게 각각 대입시켜 보는 사람으로 하여금 그래 꼭 저런 사람 있어 라는 공감과 동시에 답이 없다는 느낌을 주는 것을 의도하고 있다대사만 바꾸면 뭘 어째도 그럴듯해 보이는 만능성 때문에 트위터 및 인터넷 커뮤니티 게시판을 필두로 계속 새로운 버전이 나오고 있다 대다수의 패러디에서 원본과 다른 특징이라면 삼총사를 모아왔지라는 대사가  개노답 형제다라는 대사로 바뀌고 마지막 인물의 소개 때 그 중에서도 가장 악질인얘는 왜 지가 욕먹는지 모를꺼야이라는 대사가 자주 쓰인다보통 패러디될 때 왼쪽 인물이 가장 심각한 케이스로 묘사되고 이로 인해 대사 끝에 이 새낀 지가 왜 욕처먹는지도 모를 거야 아마 혹은이 새낀 일 거야 라는 대사가 들어가는 경우가 많다 그걸 받아주는 마지막 인물은 보통 는 하셨는지라는 말을 하는데 이를 볼 때 가장 악질 대사와 왜 욕처먹는지도 모를 거야 대사는 루리웹 버전에서부터 유래했을 가능성이 크다원작이 일본만화다 보니 우좌 방향으로 보는 사람도 있고 반대로 일반적인 좌우 방향으로 보는 사람도 있다 사실 패러디물 대부분이 어느 방향으로 봐도 지장없게 구성되긴 해서 별 얘기는 없다그 인기에 힘입어 그 후속 장면이 발굴되었다 일본만화이므로 오른쪽에서 왼쪽으로 읽을 것 일명 개노답 삼형제 속편 서로 싸우는 상황이므로 개노답성을 더 강하게 보여줄 수 있지만 싸워야 하기 때문에 상황이 한정되기도 하고 발굴 자체가 늦어져서 이 쪽 패러디는 많지 않다젤다의 전설 트라이포스 삼총사의 별명이 젤다의 전설 개노답 삼총사다 게임 특성상 싱글 플레이가 힘들다는 점과 멀티 플레이시 서로의 생각이 꼬여버리면 클리어가 힘들다는 점에서 나온 별명한 트위터리안은 아예 간단히 대사를 넣어 패러디를 만들수 있는 생성기를 만들었다 일본쪽에도 생성기가 있다 한국에서도 이미지 파일로 생성이 가능한 생성기가 있다일본의 패러디들가면라이더가면라이더 버전 개노답 삼형제가을철 피부 개노답 삼형제갑판지옥 삼형제 개노답 삼형제건담 빌드 파이터즈 트라이 버전 개노답 트라이 파이터즈건담 철혈의 오펀스 개노답 삼형제건담 시리즈 미제작인데 철혈이 건담시리즈에서 제일 악질적이긴 하다검정 고무신  개노답 삼형제게이망가 개노답 삼형제겐트위한군 간부 개노답 삼형제  장교버전 부사관 버전곤충 표본 개노답삼형제게임계 개노답 삼형제겟앰프드 개노답 삼형제기동전사 건담 시리즈의 개노답 삼형제 셋 다 동일인물인건 넘어가자니세코이 개노답 삼남매닌닌저 개노답 삼형제닌자고 개노답 삼형제내 맘대로 별 개노답 삼형제네이버 웹툰 잼민이 개노답 삼형제네티즌 개노답 삼형제다이어트 개노답 삼형제더게임툰 화도타  개노답 삼형제 개노답 삼형제  개노답 삼형제   개노답 삼형제동북아 코로나 개노답 형제디시 갤러리 개노답 삼형제디지몬 시리즈디지몬 어드벤처 트라이 개노답 삼형제디지몬 제작진 개노답 삼형제     개노답 사형제 개노답 오형제 개노답 육형제 동아리 홍보지에서조차 쓰이고 있다동방 프로젝트 개노답 삼형제 개노답 세자매이 크므로 주의바람 신령묘 삼총사 개노답 삼형제팬픽 영화 닦이 영화 삼형제디아블로  개노답 삼형제 개노답 삼형제  디자인 개노답 삼형제 해설 추가 버전실전 응용 여기서 풍자하는 주제에 대해서는 관련 항목도 참고대성마이맥 개노답 삼형제 윤도영  현직 생물 인강교사가 강의 때 써먹었다 윤도영의 나이를 생각하면 신기한 일데이트 어 라이브 아이마이미이 인조라테일 이 직접 만든 이벤트 소개한쿠페스토스트의 개노답 오역 세자매 록맨 시리즈 개발중지 완전노답 삼형제루리웹 개노답 삼형제 버전도 있다 그들의 최후리그 오브 레전드 ...

# %%
# 각 피처마다 데이터 전처리를 적용합니다.
df['title'] = df['title'].apply(lambda x: text_cleaning(x))
df['category'] = df['category'].apply(lambda x: text_cleaning(x))
df['content_text'] = df['content_text'].apply(lambda x: text_cleaning(x))
df.head(5)
# Out:
#                         title                              category  \
# 0                     라면 삼총사   맛의 달인짤방만화인터넷 밈만화 및 애니메이션문서 삭제식 이동명수
# 1                   마이애미 돌핀스                미식축구 구단플로리다 주 연고 구단년 창단
# 2  확실히 아이폰을 사고 나서 내 인생이 달라졌다                                인터넷 밈한국
# 3                    유자키 츠카사                            어쨌든 귀여워등장인물
# 4                농어촌버스 단일요금제                                  농어촌버스
#
#                                         content_text
# 0   개요 상세 구성원 기타 번역 문제 개노답 삼형제 패러디 예시원본한국어 발매본나가이...
# 1          펼치기  접기    동부북부남부서부   동부북부남부서부   동부북부남...
# 2   개요 원문 패러디 예시년 월경 스마트폰 갤러리에서 시작돼 수많은 패러디를 낳고 있...
# 3  유자키 츠카사구성츠쿠요미 츠카사나이세생일월 일신체  형배우자유자키 나사좋아하는 것애...
# 4   개요 시행 지자체 경기도개 군 강원도개 군 전라남도개 군 전라북도개 군 충청남도개...

# %% [markdown]
# # <Step2. 추출> : 키워드 추출

# %% [markdown]
# ### [텍스트 데이터 전처리]

# %%
# 텍스트 정제 함수 : 한글 이외의 문자는 전부 제거합니다.
def text_cleaning(text):
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+') # 한글의 정규표현식을 나타냅니다.
    result = hangul.sub('', text)
    return result

# %%
print(text_cleaning(df['content_text'][0]))
# Out:
#  개요 상세 구성원 기타 번역 문제 개노답 삼형제 패러디 예시원본한국어 발매본나가이 기다렸지 라면 삼총사를 데려왔단다금은면 모녀 라면 삼총사나가이 면 전문가 다이시 유조유조 여 잘 부탁합니다나가이 수프 전문가 데가와 미노루데가와 열심히 할게요 잘 부탁드립니다나가이 차슈 멘마 등 고명 전문가 타키 야스시타키 여 실례합니다맛의 달인권 라면 전쟁 편의 등장 인물들해당 에피소드는 점포를 공격적으로 확장하는 유성면으로부터 죽은 남편의 라면집 금은면을 아들과 함께 운영하는 여주인을 돕는 내용을 다루고 있다 실제 원작에선 패러디와 다르게 절대 개노답인 사람들이 아니며 오히려 저 망해가는 라면집을 살리기 위해 자신의 일인 것 마냥 무보수 무대가로 나서서 도와주는 대인배 요리사들이다 그리고 각자의 성이 다른 것에서 알 수 있듯 친형제도 아니다라면 삼총사를 소개하는 사람은 금은면 주인을 돕기 위해 지로가 찾아간 라면 종합 개발연구소의 소장 나가이 나름 라면 외길 년에 전국에 여개의 지부에 만 명 가까이 넘는 회원을 거느린 라면계의 거물 하지만 처음 본 지로 일행에게 라면이 세계를 구한다라는 구호를 외치게 하는 걸 보면 유성면의 사장 키지카와가 뛰어난 요리사라 그에 대항하기 위해 부른 게 바로 이 라면 삼총사 지금까지 다양한 라멘가게를 재건시키는 데에 성공한 라멘 가게 재건 전문가들이라고 한다 이들 역시 뛰어난 라면 요리사이긴 하지만 키지카와에게 발렸다 결국 쿠리타 유우코의 부탁을 받은 카이바라 유우잔이 방법을 가르쳐 줘서 이긴다 물론 카이바라는 마지막 힌트만 준 것이고 기본적인 틀은 이 세 명이 잡아준 것이다어쨌든 요리 승부에 패한 키지카와는 결과를 받아들이고 물러선다 참고로 키지카와는 일단 적으로 나왔고 다소 독선적인 면은 있지만 뛰어난 요리사인데다 사장으로서의 마인드도 훌륭한 인물이다이후의 에피소드에서도 일본 라면 총합개발연구원 소장인 나가이나 금은면의 인물들은 재등장하지만 그들이 다시 등장하는 일은 없었다 엄밀히 말하자면 이들은 가게 재건 전문가인 만큼 자주 등장시키기 어렵다는 점도 고려해야겠지만다이시 유조면 전문가 작중에서는 면의 재질이나 식감 더 나아가서 밀가루 선정까지 관여했기에 제법 활약이 컸다데가와 미노루수프국물 전문가 면 다음으로 중요한 분야인 만큼 그럭저럭 옆에서 코치해주었다타키 야스시고명 전문가 본인은 옆에서 고명의 중요성을 설파하기는 했지만 안타깝게도 가장 활약이 없었다 각종 패러디짤에서는 끝마무리를 장식하는 포지션으로 대부분 가장 노답인 사례를 담당하고 있다본 에피소드의 영향인지 훗날 연재된 다른 요리 만화에서도 라멘 가게를 경영하는 내용을 다룰 경우엔 등장인물 서너 명이 경영 부진을 겪는 가게를 돕는 전개가 나올 때가 있다 그 때마다 일본 웹상에서는 해당 작품의 묘사와 삼총사의 행적을 비교하기도 한다맛의 달인 애니판은 권까지의 내용만 다루고 있기 때문에 권에 나오는 본 인물들은 출연하지 않는다야한 이야기라는 개념이 존재하지 않는 지루한 세계 애니판에서는 느닷없이 학생회장을 습격하는 스토커 역할로 카메오 출연하기도 했다참고로 마지막 컷의 번역은 오역이다 말풍선의 표시를 보면 오른쪽 말풍선은 왼쪽과 달리 말하는 당사자를 표시해주는 뾰족한 부분이 없는 칸 바깥 인물의 대사인 것을 알 수 있다 극 용어로 치면 보이스오버 처음엔 라면 전문가들을 모아왔지라며 반말즉 말투 중 해체을 사용하다가 소개 부분에선 존댓말을 쓰는 것도 오류아마도 번역자는 하단 세 칸의 말풍선 내 대사들 전부가 라면 삼총사 각자 직접 한 말로 착각한 것 같은데 실제로는 먼저 오른쪽에서 칸 바깥의 나가이 소장이 인물에 대한 소개를 하고 나서 그에 대해 소개된 본인이 인사하는 것으로 이해하는 것이 정확하다 게다가 마지막 사람은 소개마저도 미묘하게 잘못 번역되었다 차슈 말린 죽순 등 고명 전문가라고 번역해야 했다 정발번역만 보면 원래 차슈와 말린 죽순은 고명의 일종인데 마치 차슈와 말린 죽순이 고명과 동격인 것처럼 보인다작중에서는 어디까지나 라면에 대한 지식과 조력을 담당하는 단역들에 불과했으나 그 개성적인 외모와 옷차림이 주는 임팩트 그리고 여러모로 활용도가 높은 소개 장면의 컷 구성으로 인해 온갖 답이 없는 것들로 패러디되기 시작했다문제의 컷은 후타바 채널에서 진즉에 패러디 짤로 돌아다니다가 년 월경부터 트위터에서 패러디 소재로 재발굴되며 급속도로 유행하기 시작했다 이렇게 생겨난 각종 인터넷 짤방들은 한국에 전파되면서 라면 삼총사 대신 대부분 개노답 삼형제라는 별칭으로 알려져있으며 그 외로 개노답 삼총사 개노답 삼인방 등으로도 불린다본래 일본에서 유행하던 것이 건너온 것이며 어떠한 주제에 대한 세 가지의 악례를 세 사람에게 각각 대입시켜 보는 사람으로 하여금 그래 꼭 저런 사람 있어 라는 공감과 동시에 답이 없다는 느낌을 주는 것을 의도하고 있다대사만 바꾸면 뭘 어째도 그럴듯해 보이는 만능성 때문에 트위터 및 인터넷 커뮤니티 게시판을 필두로 계속 새로운 버전이 나오고 있다 대다수의 패러디에서 원본과 다른 특징이라면 삼총사를 모아왔지라는 대사가  개노답 형제다라는 대사로 바뀌고 마지막 인물의 소개 때 그 중에서도 가장 악질인얘는 왜 지가 욕먹는지 모를꺼야이라는 대사가 자주 쓰인다보통 패러디될 때 왼쪽 인물이 가장 심각한 케이스로 묘사되고 이로 인해 대사 끝에 이 새낀 지가 왜 욕처먹는지도 모를 거야 아마 혹은이 새낀 일 거야 라는 대사가 들어가는 경우가 많다 그걸 받아주는 마지막 인물은 보통 는 하셨는지라는 말을 하는데 이를 볼 때 가장 악질 대사와 왜 욕처먹는지도 모를 거야 대사는 루리웹 버전에서부터 유래했을 가능성이 크다원작이 일본만화다 보니 우좌 방향으로 보는 사람도 있고 반대로 일반적인 좌우 방향으로 보는 사람도 있다 사실 패러디물 대부분이 어느 방향으로 봐도 지장없게 구성되긴 해서 별 얘기는 없다그 인기에 힘입어 그 후속 장면이 발굴되었다 일본만화이므로 오른쪽에서 왼쪽으로 읽을 것 일명 개노답 삼형제 속편 서로 싸우는 상황이므로 개노답성을 더 강하게 보여줄 수 있지만 싸워야 하기 때문에 상황이 한정되기도 하고 발굴 자체가 늦어져서 이 쪽 패러디는 많지 않다젤다의 전설 트라이포스 삼총사의 별명이 젤다의 전설 개노답 삼총사다 게임 특성상 싱글 플레이가 힘들다는 점과 멀티 플레이시 서로의 생각이 꼬여버리면 클리어가 힘들다는 점에서 나온 별명한 트위터리안은 아예 간단히 대사를 넣어 패러디를 만들수 있는 생성기를 만들었다 일본쪽에도 생성기가 있다 한국에서도 이미지 파일로 생성이 가능한 생성기가 있다일본의 패러디들가면라이더가면라이더 버전 개노답 삼형제가을철 피부 개노답 삼형제갑판지옥 삼형제 개노답 삼형제건담 빌드 파이터즈 트라이 버전 개노답 트라이 파이터즈건담 철혈의 오펀스 개노답 삼형제건담 시리즈 미제작인데 철혈이 건담시리즈에서 제일 악질적이긴 하다검정 고무신  개노답 삼형제게이망가 개노답 삼형제겐트위한군 간부 개노답 삼형제  장교버전 부사관 버전곤충 표본 개노답삼형제게임계 개노답 삼형제겟앰프드 개노답 삼형제기동전사 건담 시리즈의 개노답 삼형제 셋 다 동일인물인건 넘어가자니세코이 개노답 삼남매닌닌저 개노답 삼형제닌자고 개노답 삼형제내 맘대로 별 개노답 삼형제네이버 웹툰 잼민이 개노답 삼형제네티즌 개노답 삼형제다이어트 개노답 삼형제더게임툰 화도타  개노답 삼형제 개노답 삼형제  개노답 삼형제   개노답 삼형제동북아 코로나 개노답 형제디시 갤러리 개노답 삼형제디지몬 시리즈디지몬 어드벤처 트라이 개노답 삼형제디지몬 제작진 개노답 삼형제     개노답 사형제 개노답 오형제 개노답 육형제 동아리 홍보지에서조차 쓰이고 있다동방 프로젝트 개노답 삼형제 개노답 세자매이 크므로 주의바람 신령묘 삼총사 개노답 삼형제팬픽 영화 닦이 영화 삼형제디아블로  개노답 삼형제 개노답 삼형제  디자인 개노답 삼형제 해설 추가 버전실전 응용 여기서 풍자하는 주제에 대해서는 관련 항목도 참고대성마이맥 개노답 삼형제 윤도영  현직 생물 인강교사가 강의 때 써먹었다 윤도영의 나이를 생각하면 신기한 일데이트 어 라이브 아이마이미이 인조라테일 이 직접 만든 이벤트 소개한쿠페스토스트의 개노답 오역 세자매 록맨 시리즈 개발중지 완전노답 삼형제루리웹 개노답 삼형제 버전도 있다 그들의 최후리그 오브 레전드 ...

# %%
# 각 피처마다 데이터 전처리를 적용합니다.
df['title'] = df['title'].apply(lambda x: text_cleaning(x))
df['category'] = df['category'].apply(lambda x: text_cleaning(x))
df['content_text'] = df['content_text'].apply(lambda x: text_cleaning(x))
df.head(5)
# Out:
#                         title                              category  \
# 0                     라면 삼총사   맛의 달인짤방만화인터넷 밈만화 및 애니메이션문서 삭제식 이동명수
# 1                   마이애미 돌핀스                미식축구 구단플로리다 주 연고 구단년 창단
# 2  확실히 아이폰을 사고 나서 내 인생이 달라졌다                                인터넷 밈한국
# 3                    유자키 츠카사                            어쨌든 귀여워등장인물
# 4                농어촌버스 단일요금제                                  농어촌버스
#
#                                         content_text
# 0   개요 상세 구성원 기타 번역 문제 개노답 삼형제 패러디 예시원본한국어 발매본나가이...
# 1          펼치기  접기    동부북부남부서부   동부북부남부서부   동부북부남...
# 2   개요 원문 패러디 예시년 월경 스마트폰 갤러리에서 시작돼 수많은 패러디를 낳고 있...
# 3  유자키 츠카사구성츠쿠요미 츠카사나이세생일월 일신체  형배우자유자키 나사좋아하는 것애...
# 4   개요 시행 지자체 경기도개 군 강원도개 군 전라남도개 군 전라북도개 군 충청남도개...

# %% [markdown]
# # 말뭉치 만들기

# %%
# 각 피처마다 말뭉치를 생성합니다.
title_corpus = "".join(df['title'].tolist())
category_corpus = "".join(df['category'].tolist())
content_corpus = "".join(df['content_text'].tolist())
print(title_corpus)
# Out:
# 라면 삼총사 마이애미 돌핀스 확실히 아이폰을 사고 나서 내 인생이 달라졌다 유자키 츠카사 농어촌버스 단일요금제 유스타스 키드작중 행적 환승저항 분노 김명수법조인 파일정수진꽉잡아오프닝 칠죄종 아이돌 마스터 소셜 게임 꿈의 마녀 강선구 스타워즈 시퀄 시리즈  전쟁 앵커리지 이매진 브레이커 조나탕 아파레시두 다 시우바 아카메가 벤다      프린세스 커넥트 주제가 고비다이 부산  소닉붐 심연의 감시자 그리폰포 아너 소맥거핀작품등장인물   등장인물 중급닌자 양기철 수리노을 랑코 한국바둑리그시즌전반기 사피론 고스트 오브 쓰시마 캄차카 화산군       결산 여자대학교 신밧드의 모험롯데월드 어드벤처 아잉켄슈타인 송시열 색욕 집사부일체년     결승  트윈스년월 마가키 가산동 라스베이거스 레이더스   인테르나치오날레 밀라노 시즌리그 히메지마 아케노 대 닥터 첼로 미니파이터 환타지 드림 배치기가수 엘리아스 테오도로 복무 부적격자 틀역대  준플레이오프 목록 파일  전속부관 순천향대학교출신 인물    팁 인퀴지터리우스 배로나  골든글러브 역대 수상자  플레이오프년 히가시네무로역 퍼시 비시 셸리 뷰티풀 군바리등장인물소대 아르민 알레르토작중 행적 대전천  리그년신인드래프트 시라이와 유나 이진솔 철인왕후드라마  카트라이더 리그 시즌 사람을 낚는 어부  틀그랜드체이스  영웅등급 이동진평론가올해의 영화 목록 일본

# %% [markdown]
# # [konlpy를 이용한 키워드 추출]

# %% [markdown]
# - 아래 코드 실행을 위해, anaconda prompt 혹은 Terminal에서 아래와 같은 패키지들을 설치해 줍니다.
# - 아래의 방법으로 설치해도 실행되지 않는다면, http://konlpy.org/ko/latest/install/ 를 참고하세요.
#     - Install
#         - 1. Java를 설치합니다. (https://java.com/ko/download/)
#         - 2. c++ 컴파일러를 설치합니다.
#             - 윈도우 : `Microsoft Visual C++ 14.0` 설치 권장, https://visualstudio.microsoft.com/ko/downloads/
#             - Mac OS : `Xcode` 설치 권장
#             - Linux : `gcc` 설치 권장
#         - 3. 아래와 같은 파이썬 패키지를 설치합니다. **konlpy 버전을 반드시 0.5.1로 해주어야 합니다. 2020년 현재(9월) 기준, 최신 버전 konlpy 에서는 일부 개발환경에서 자바 에러가 발생합니다.**
#             - (env_name) `pip install konlpy==0.5.1`
#             - (env_name) `pip install jpype1`
#             - (env_name) `pip install Jpype1-py3`

# %%
from konlpy.tag import Okt
from collections import Counter

# konlpy의 형태소 분석기로 명사 단위의 키워드를 추출합니다.
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(content_corpus)
count = Counter(nouns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-c2084daf2362> in <module>
# ----> 1 from konlpy.tag import Okt
#       2 from collections import Counter
#       3
#       4 # konlpy의 형태소 분석기로 명사 단위의 키워드를 추출합니다.
#       5 nouns_tagger = Okt()
#
# /usr/local/lib/python3.7/site-packages/konlpy/__init__.py in <module>
#       8     pass
#       9
# ---> 10 from konlpy.jvm import init_jvm
#      11 from konlpy import (
#      12     corpus,
#
# /usr/local/lib/python3.7/site-packages/konlpy/jvm.py in <module>
#       6 import sys
#       7 try:
# ----> 8     import jpype
#       9 except ImportError:
#      10     pass
#
# ~/.local/lib/python3.7/site-packages/jpype/__init__.py in <module>
#      18 import _jpype
#      19 from ._jinit import *
# ---> 20 from ._jpackage import *
#      21 from ._jproxy import *
#      22 from ._core import *
#
# ~/.local/lib/python3.7/site-packages/jpype/_jpackage.py in <module>
#      29
#      30
# ---> 31 class JPackage(_jpype._JPackage, metaclass=_JPackageMeta):
#      32     """ Gateway for automatic importation of Java classes.
#      33
#
# AttributeError: module '_jpype' has no attribute '_JPackage'

# %%
count

# %% [markdown]
# # 키워드 가다듬기

# %%
# 한글자 키워드를 제거합니다.
remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
print(remove_char_counter)

# %% [markdown]
# # 불용어 제거

# %%
# 한국어 약식 불용어사전 예시 파일입니다. 출처 - (https://www.ranks.nl/stopwords/korean)
korean_stopwords_path = "../data/korean_stopwords.txt"

# 텍스트 파일을 오픈합니다.
with open(korean_stopwords_path, encoding='utf8') as f:
    stopwords = f.readlines()
stopwords = [x.strip() for x in stopwords]
print(stopwords[:10])

# %%
# 나무위키 페이지에 맞는 불용어를 추가합니다.
namu_wiki_stopwords = ['상위', '문서', '내용', '누설', '아래', '해당', '설명', '표기', '추가', '모든', '사용', '매우', '가장',
                       '줄거리', '요소', '상황', '편집', '틀', '경우', '때문', '모습', '정도', '이후', '사실', '생각', '인물', 
                       '이름', '년월']
for stopword in namu_wiki_stopwords:
    stopwords.append(stopword)

# %%
# 키워드 데이터에서 불용어를 제거합니다.
remove_char_counter = Counter({x : remove_char_counter[x] for x in count if x not in stopwords})
print(remove_char_counter)

# %% [markdown]
# # <Step3. 시각화> : 워드 클라우드 시각화

# %% [markdown]
# # [pytagcloud 사용하기]

# %% [markdown]
# - 아래 코드 실행을 위해, anaconda prompt 혹은 Terminal에서 아래와 같은 패키지들을 설치해 줍니다.
#     - (env_name) `pip install pytagcloud pygame simplejson`
# - 그리고 아래와 같은 경로에 한글 폰트(예: NanumBarunGothic.ttf) 파일을 옮깁니다.
#     - Mac OS : /{anaconda_path}/envs/{env_name}/lib/python3.7/site-packages/pytagcloud/fonts
#     - Windosw OS : \{anaconda_path}\envs\{env_name}\Lib\site-packages\pytagcloud\fonts
#     - `폰트 다운로드 : http://hangeul.naver.com/webfont/NanumGothic/NanumGothic.ttf`
# - 파일을 옮긴 후, 파이썬 가상환경을 재실행 하여 주피터를 다시 실행해줍니다. 그래도 아래의 코드가 실행되지 않는 경우는 다음과 같은 작업을 수행합니다.
#     - 위의 경로에서 font.json 파일을 편집합니다.
#     - 아래와 같은 코드를 추가하고 font.json 파일을 저장합니다.
#     - {
#                 "name": "NanumGothic",
#                 "ttf": "NanumGothic.ttf",
#                 "web": "http://fonts.googleapis.com/css?family=Nanum+Gothic"
#         },

# %%
import random
import pytagcloud
import webbrowser

# 가장 출현 빈도수가 높은 40개의 단어를 선정합니다.
ranked_tags = remove_char_counter.most_common(40)

# pytagcloud로 출력할 40개의 단어를 입력합니다. 단어 출력의 최대 크기는 80으로 제한합니다.
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)

# pytagcloud 이미지를 생성합니다. 폰트는 나눔 고딕을 사용합니다.
pytagcloud.create_tag_image(taglist, 'wordcloud.jpg', size=(900, 600), fontname='NanumGothic', rectangular=False)

# %%
# 생성한 이미지를 주피터 노트북상에서 출력합니다.
from IPython.display import Image
Image(filename='wordcloud.jpg')

# %% [markdown]
# # [나무위키 키워드 시각화]

# %% [markdown]
# # 제목 키워드

# %%
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(title_corpus)
count = Counter(nouns)

remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
remove_char_counter = Counter({x : remove_char_counter[x] for x in count if x not in stopwords})

ranked_tags = remove_char_counter.most_common(40)
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)
pytagcloud.create_tag_image(taglist, 'title_wordcloud.jpg', size=(900, 600), fontname='NanumGothic', rectangular=False)

Image(filename='title_wordcloud.jpg')

# %% [markdown]
# # 카테고리 키워드

# %%
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(category_corpus)
count = Counter(nouns)

remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
remove_char_counter = Counter({x : remove_char_counter[x] for x in count if x not in stopwords})

ranked_tags = remove_char_counter.most_common(40)
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)
pytagcloud.create_tag_image(taglist, 'category_wordcloud.jpg', size=(900, 600), fontname='NanumGothic', rectangular=False)

Image(filename='category_wordcloud.jpg')
